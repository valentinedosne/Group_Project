# %%
class borrowable_amount : 
    def amount_credit(person, time_credit): 
    total = is_elegible(person)
    max_amount = 0
    rate = 0
    
    if (total == 100):
        return 0
    
    else: 
        if (total > 75): 
            if (time_credit == "Short"): 
                max_amount = 100
                rate = 4.8
            if (time_credit == "Mid"): 
                max_amount = 105
                rate = 4.6
            if (time_credit == "Long"): 
                max_amount = 110
                rate = 4.5
        
        if (total < 75) and (total > 50): 
            if (time_credit == "Short"): 
                max_amount = 150
                rate = 3.8
            if (time_credit == "Mid"): 
                max_amount = 165
                rate = 3.7
            if (time_credit == "Long"): 
                max_amount = 170
                rate = 3.6
        
        if (total < 50) and (total > 20): 
            if (time_credit == "Short"): 
                max_amount = 170
                rate = 3.2
            if (time_credit == "Mid"): 
                max_amount = 195
                rate = 3.3
            if (time_credit == "Long"): 
                max_amount = 200
                rate = 3.4
        
        if (total < 20): 
            if (time_credit == "Short"): 
                max_amount = 300
                rate = 3
            if (time_credit == "Mid"): 
                max_amount = 450
                rate = 2.9
            if (time_credit == "Long"): 
                max_amount = 500
                rate = 2.8
        
        print("According to your profil, you can borrow up to", max_amount, "K, with", rate, "% interest rate")
        return max_amount
    
    
    def can_borrow(person, amount_K, years): 
    time = ""
    if (years < 5): 
        time = "Short"
    if (years >= 5) and (years < 10): 
        time = "Mid"
    if (years >= 10): 
        time = "Long"
    
    max_amount = amount_credit(person, time)
    
    if (amount_K < max_amount): 
        print("So, yes, you can borrow", amount_K, "K on", years, "years")
        return True
    else: 
        print("So sorry, you can't borrow", amount_K, "K on", years, "years")
        return False
